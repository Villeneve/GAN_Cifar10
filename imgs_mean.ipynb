# %%
import tensorflow as tf
import keras
import matplotlib.pyplot as plt

# %%
(x,y),(_,_) = keras.datasets.cifar10.load_data()

# %%
img = tf.reduce_mean(x[y[:,0] == 1],axis=0)
plt.matshow(img)
plt.show()
